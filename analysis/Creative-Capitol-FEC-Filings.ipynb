# %% [markdown]
# # Creative Capitol FEC Filings

# %% [markdown]
# Using FEC Disbursements to look at the cost of creative services in U.S. Political Campaigns

# %% [markdown]
# ##### Imports

# %%
#Import libraries
import pandas as pd
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('max_seq_item', None)

# %% [markdown]
# ##### FEC API

# %% [markdown]
# https://api.open.fec.gov/developers/
#
# https://api.open.fec.gov/developers/#/search

# %% [markdown]
# API Key = 1d4FL1ITomWsY51hgi0HjixVu6J0yMzWB4ThdLgI

# %% [markdown]
# Disbursement Categories
# https://www.fec.gov/campaign-finance-data/disbursement-category-code-descriptions/

# %% [markdown]
# Disbursement category codes for non-presidential filers:
#
# * 001	Administrative/salary/overhead expenses (e.g., rent, staff salaries, postage, office supplies, equipment, furniture, ballot access fees, petition drives, party fees and legal and accounting expenses)
# * 003	Solicitation and fundraising expenses (e.g., costs for direct mail solicitations and fundraising events including printing, mailing lists, consultant fees, call lists, invitations, catering costs and room rental)
# * 004	Advertising expenses -including general public political advertising (e.g., purchases of radio/television broadcast/cable time, print advertisements and related production costs)
# * 006	Campaign materials (e.g., buttons, bumper stickers, brochures, mass mailings, pens, posters, balloons)
#
#
# Disbursement category codes for presidential filers:
# * 102	Media expenditures
# * 103	Expenditures for mass mailings and other campaign materials (e.g., buttons, bumper stickers, brochures, mass mailings, pens, posters, balloons)
# * 104	Overhead expenditures of state offices and their facilities (e.g., rent, staff salaries, postage, office supplies, equipment, furniture, ballot access fees, petition drives, party fees and legal and accounting expenses)
# * 107	Fundraising expenditures (e.g., costs for direct mail solicitations & fundraising events including printing, mailing lists, consultant fees, call lists, invitations, catering costs and room rental)

# %% [markdown]
# FEC Disbursement Description Search Example: https://www.fec.gov/data/disbursements/?spender_committee_type=S&data_type=processed&max_date=03%2F06%2F2022&disbursement_description=graphics&disbursement_description=graphic

# %% [markdown]
# ##### Examples of Creative Related Expenses by Campaigns

# %% [markdown]
# Goal: Determine potential query terms for the FEC database by researching terms used by a known creative agency, Wide Eye, a disbursement recipient doing campaign graphics work

# %%
df_wideeye = pd.read_csv("..//data//source//FEC//schedule_b-2022-03-06T09_25_48_wideeye.csv", encoding="utf-8")

# %%
df_wideeye.head(20)
# Out:
#    committee_id               committee_name  report_year report_type  \
# 0     C00193433                 EMILY'S LIST         2021          YE
# 1     C00495861        PRIORITIES USA ACTION         2021          YE
# 2     C00574889           TAMMY FOR ILLINOIS         2021          Q1
# 3     C00344473       STABENOW FOR US SENATE         2021          YE
# 4     C00588772                MAGGIE FOR NH         2021          Q1
# 5     C00588772                MAGGIE FOR NH         2021          Q1
# 6     C00639054     DEB HAALAND FOR CONGRESS         2021          Q1
# 7     C00341396  MOVEON.ORG POLITICAL ACTION         2021         30R
# 8     C00696526        MARK KELLY FOR SENATE         2021          Q1
# 9     C00495358           KAINE FOR VIRGINIA         2021          Q1
# 10    C00709899        SARA GIDEON FOR MAINE         2021          Q3
# 11    C00770602           RHODA FOR CONGRESS         2021          Q2
# ...

# %%
df_wideeye.disbursement_description
# Out:
# 0                                   WEBSITE DEVELOPMENT & DESIGN
# 1                  NON-CONTRIBUTION ACCOUNT: WEBSITE DEVELOPMENT
# 2                                               WEBSITE SERVICES
# 3                                                        WEBSITE
# 4                                                WEBSITE HOSTING
# 5                                                WEBSITE HOSTING
# 6                                                     WEB DESIGN
# 7                                 PROGRAM DEVELOPMENT CONSULTANT
# 8                                               WEBSITE SERVICES
# 9                                                WEBSITE SUPPORT
# 10                                           WEBSITE DEVELOPMENT
# 11    FUNDRAISING VENUE INCLUDING BARTENDER AND BARISTA SERVICES
# 12                                PROGRAM DEVELOPMENT CONSULTANT
# 13                                PROGRAM DEVELOPMENT CONSULTANT
# ...

# %%
df_wideeye.disbursement_description.unique()
# Out:
# array(['WEBSITE DEVELOPMENT & DESIGN',
#        'NON-CONTRIBUTION ACCOUNT: WEBSITE DEVELOPMENT',
#        'WEBSITE SERVICES', 'WEBSITE', 'WEBSITE HOSTING', 'WEB DESIGN',
#        'PROGRAM DEVELOPMENT CONSULTANT', 'WEBSITE SUPPORT',
#        'WEBSITE DEVELOPMENT',
#        'FUNDRAISING VENUE INCLUDING BARTENDER AND BARISTA SERVICES',
#        'WEB HOSTING', 'WEBSITE MAINTENANCE',
#        'WEBSITE HOSTING-REPLACES CHECK #25206'], dtype=object)

# %% [markdown]
# 'WEBSITE DEVELOPMENT & DESIGN',
#        'NON-CONTRIBUTION ACCOUNT: WEBSITE DEVELOPMENT',
#        'WEBSITE SERVICES',
#        'WEBSITE',
#        'WEBSITE HOSTING',
#        'WEB DESIGN',
#        'PROGRAM DEVELOPMENT CONSULTANT',
#        'WEBSITE SUPPORT',
#        'WEBSITE DEVELOPMENT',
#        'FUNDRAISING VENUE INCLUDING BARTENDER AND BARISTA SERVICES',
#        'WEB HOSTING',
#        'WEBSITE MAINTENANCE',
#        'WEBSITE HOSTING-REPLACES CHECK #25206']

# %% [markdown]
# Disbursements for Website-related Services

# %%
df_website = pd.read_csv("..//data//source//FEC//schedule_b-2022-03-06T11_19_30_website.csv")
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (15,31,32,50,54,64,74,75,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_website.head()
# Out:
#   committee_id                              committee_name  report_year  \
# 0    C00394395                       HUNZEKER FOR CONGRESS         2004
# 1    C00300921  BLACK AMERICA'S POLITICAL ACTION COMMITTEE         2004
# 2    C00399907                       NEWBERRY FOR CONGRESS         2004
# 3    C00365015            COMMITTEE TO ELECT LINCOLN DAVIS         2004
# 4    C00392266                      STREUSAND FOR CONGRESS         2004
#
#   report_type  image_number line_number transaction_id  file_number  \
# 0          Q2   24962140808          17       EXP:B:71       131870
# 1          Q3   25980146785         21B    SB21B.37070       158644
# 2         12P   24961973931          17      SB17.4856       129227
# 3          Q3   24981789481          17     SB17.13726       156587
# 4         12R   24990911003          17      SB17.4601       113365
#
#   entity_type entity_type_desc unused_recipient_committee_id  \
# ...

# %%
len(df_website)
# Out:
# 93589

# %% [markdown]
# Disbursements for Logo-related Services

# %%
df_logo = pd.read_csv("..//data//source//FEC//schedule_b-2022-03-06T11_45_52_logo.csv")

# %%
df_logo.head()
# Out:
#   committee_id                                       committee_name  \
# 0    C00153379  SIERRA PACIFIC EMPLOYEES POLITICAL ACTION COMMITTEE
# 1    C00394833                             SANDY LYONS FOR CONGRESS
# 2    C00254185                    GENE GREEN CONGRESSIONAL CAMPAIGN
# 3    C00401703                                  FRIENDS OF ALJANICH
# 4    C00385955                                 HERLONG FOR CONGRESS
#
#    report_year report_type  image_number line_number transaction_id  \
# 0         2004          Q1   24990974223         21B     SB21B.4326
# 1         2004          Q1   24990967119          17      SB17.4288
# 2         2004          Q2   24961810449          17      SB17.9170
# 3         2004          Q2   24971485699          17      SB17.4307
# 4         2003         TER   23991255864          21      SB21.4500
#
#    file_number entity_type entity_type_desc unused_recipient_committee_id  \
# ...

# %%
# df_logo.disbursement_description

# %%
len(df_logo)
# Out:
# 2742

# %% [markdown]
# Disbursement for Design-related Services

# %%
df_design = pd.read_csv("..//data//source//FEC//schedule_b-2022-03-06T11_50_56_design.csv")
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (15,64,74,75,76,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_design.head()
# Out:
#   committee_id            committee_name  report_year report_type  \
# 0    C00564948   PAUL SPAIN FOR CONGRESS         2015          YE
# 1    C00583005  JESSE SBAIH FOR CONGRESS         2015          YE
# 2    C00505776       FRIENDS OF MIA LOVE         2016         12G
# 3    C00566174   TEA PARTY MAJORITY FUND         2016          Q1
# 4    C00620369     HOUSE LIBERTY PROJECT         2016         30G
#
#          image_number line_number transaction_id  file_number entity_type  \
# 0  201601149004484378          17      SB17.4691      1039612         ORG
# 1  201601139004479498          17    VQZA8A1G006      1039411         IND
# 2  201701179041407967          17     SB17.I3356      1139302         ORG
# 3  201910029163583164         21B     SB21B.4235      1354442         ORG
# 4  201612089039991452         21B     SB21B.4239      1133212         ORG
#
#   entity_type_desc unused_recipient_committee_id recipient_committee_id  \
# ...

# %%
len(df_design)
# Out:
# 47244

# %% [markdown]
# Disbursement for Graphic-related or Graphics-related Services

# %%
df_graphic = pd.read_csv("..//data//source//FEC//schedule_b-2022-03-07T12_54_12_graphic.csv")
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (32,64) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_graphic.head()
# Out:
#   committee_id                               committee_name  report_year  \
# 0    C00343475                       TODD AKIN FOR CONGRESS         2005
# 1    C00396325  COMMITTEE TO ELECT JOHN RUSSELL TO CONGRESS         2005
# 2    C00413674                     STEVE YOUNG FOR CONGRESS         2005
# 3    C00193433                                 EMILY'S LIST         2005
# 4    C00193433                                 EMILY'S LIST         2005
#
#   report_type  image_number line_number transaction_id  file_number  \
# 0          Q3   25971165571          17     SB17.16859       188839
# 1          YE   26990167771          17      SB17.4163       198471
# 2         12R   25971545941          17         B17142       192557
# 3          M9   26980097606         21B    SB21B-77321       201615
# 4         M12   26960130301         21B    SB21B-80415       221189
#
#   entity_type entity_type_desc unused_recipient_committee_id  \
# ...

# %%
len(df_graphic)
# Out:
# 15709

# %%
frames = [df_website, df_logo, df_design, df_graphic]

# %%
df = pd.concat(frames)

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#   committee_id                              committee_name  report_year  \
# 0    C00394395                       HUNZEKER FOR CONGRESS         2004
# 1    C00300921  BLACK AMERICA'S POLITICAL ACTION COMMITTEE         2004
# 2    C00399907                       NEWBERRY FOR CONGRESS         2004
# 3    C00365015            COMMITTEE TO ELECT LINCOLN DAVIS         2004
# 4    C00392266                      STREUSAND FOR CONGRESS         2004
#
#   report_type  image_number line_number transaction_id  file_number  \
# 0          Q2   24962140808          17       EXP:B:71       131870
# 1          Q3   25980146785         21B    SB21B.37070       158644
# 2         12P   24961973931          17      SB17.4856       129227
# 3          Q3   24981789481          17     SB17.13726       156587
# 4         12R   24990911003          17      SB17.4601       113365
#
#   entity_type entity_type_desc unused_recipient_committee_id  \
# ...

# %%
len(df)
# Out:
# 144892

# %% [markdown]
# -----

# %% [markdown]
# ##### Using WashPo's FastFec API

# %% [markdown]
# https://github.com/washingtonpost/FastFEC/tree/develop/python

# %%
# pip install fastfec

# %%
from fastfec import FastFEC

# %% [markdown]
# {filing_id}_{form_type}

# %%
# from fastfec import FastFEC
# with open('14823832.fec', 'rb') as f:
#     with FastFEC() as fastfec:
#         for form, line in fastfec.parse(f):
#             print("GOT", form, line)

# %% [markdown]
# Fast FEC
